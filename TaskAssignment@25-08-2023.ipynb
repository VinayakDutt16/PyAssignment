# %%
'''Question : Take a input from the user and do the following task

- if user provide input 1
    print the current data of your os system
- user =>2
    create a folder with name regex on Desktop
- user => 3
    copy the current file in the regex folder on Desktop
- user => 4
    open a browser and search regexsoftware on google
    ( no manual work)
- user => 5
    Drop a whatsapp msg to Nidhi mam
    - This is Python Assignment given by tushar sir
    ( only with program)'''
import os
print("Tasks :")
print("1.Print the current data of your os system")
print("2.Create a folder with name regex on Desktop")
print("3.Copy the current file in the regex folder on Desktop")
print("4.Open a browser and search regexsoftware on google")
print("5.Drop a whatsapp msg to Nidhi mam")
ch=int(input("ENTER YOUR CHOICE :"))
if(ch==1):
    from datetime import date
    today = date.today()
    print("Today Date is :",today)
elif(ch==2):
    path = os.getcwd()
    print("The current working directory %s" % path)
    os.chdir("/Users/HP/OneDrive/Desktop") #changing directory
    path = os.getcwd()
    print("The current working directory %s" % path)
    path='./regex'
    if not os.path.exists(path): #ToRem if folder not exist already
        os.mkdir(path)           #making directory or folder
        print("Folder %s is created"% path)
    else:
        print("Folder %s already exists"% path)
elif(ch==3):
    #ToRem Using shutil module : it offers a number of high-level
    import shutil
    src_path = r"C:/Users/HP/TaskAssignment@25-08-2023.ipynb"
    dst_path = r"C:/Users/HP/OneDrive/Desktop/regex"
    shutil.copy(src_path, dst_path)
    print("Copied!!")
elif(ch==4):
    import webbrowser
    url = "https://www.google.com/search?q=regex+software"
    webbrowser.open(url)
elif(ch==5):

    
    import pywhatkit
    pywhatkit.start_server()

    pywhatkit.sendwhatmsg_instantly(
    phone_no="+917852069974", 
    message="This is Python Assignment given by tushar sir)"
    )
else:
    print("Wrong Choice!!")
# Out:
# Tasks :
# 1.Print the current data of your os system
# 2.Create a folder with name regex on Desktop
# 3.Copy the current file in the regex folder on Desktop
# 4.Open a browser and search regexsoftware on google
# 5.Drop a whatsapp msg to Nidhi mam
# ENTER YOUR CHOICE :5
# Server started at local_ip_of_this_pc:8000
# Print Ctrl+C to exit

# %%
# Out:
# ...
#
# ...
#                                               0.0/61.2 kB ? eta -:--:--
#      ---------------------------------        51.2/61.2 kB ? eta -:--:--
#      -------------------------------------- 61.2/61.2 kB 822.5 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
# ...
